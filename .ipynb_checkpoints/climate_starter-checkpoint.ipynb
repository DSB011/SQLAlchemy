# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, inspect

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# Calculate the date 1 year ago from the last data point in the database

# Perform a query to retrieve the data and precipitation scores

# Save the query results as a Pandas DataFrame and set the index to the date column

# Sort the dataframe by date

# Use Pandas Plotting with Matplotlib to plot the data

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# Get column names for Measurement 
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Get column names for Station 
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Find the most recent date:
recent_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
recent_date
# Out:
# ('2017-08-23')

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
percipitation_last_12_months = session.query(Measurement.date, Measurement.prcp).\
filter(Measurement.date >='2016-08-24').filter(Measurement.date <='2017-08-23').order_by(Measurement.date).all()

percipitation_last_12_months
# Out:
# [('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.17),
#  ('2016-08-29', 0.04),
#  ('2016-08-29', None),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.35),
#  ('2016-08-29', 0.9),
#  ('2016-08-30', 0.0),
# ...

# %%
#Save the query results as a Pandas DataFrame and set the index to the date column
percipitation_last_12_months_df = pd.DataFrame(percipitation_last_12_months, columns=["date", "percipitation"])
percipitation_last_12_months_df.set_index("date")
percipitation_last_12_months_df.head(10)
# Out:
#          date  percipitation
# 0  2016-08-24           0.08
# 1  2016-08-24           2.15
# 2  2016-08-24           2.28
# 3  2016-08-24            NaN
# 4  2016-08-24           1.22
# 5  2016-08-24           2.15
# 6  2016-08-24           1.45
# 7  2016-08-25           0.08
# 8  2016-08-25           0.08
# 9  2016-08-25           0.00

# %%
# Sort the dataframe by date
percipitation_last_12_months_df.sort_values(by=["date"])
percipitation_last_12_months_df.head()
# Out:
#          date  percipitation
# 0  2016-08-24           0.08
# 1  2016-08-24           2.15
# 2  2016-08-24           2.28
# 3  2016-08-24            NaN
# 4  2016-08-24           1.22

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
percipitation_last_12_months_df.describe()
# Out:
#        percipitation
# count    2015.000000
# mean        0.176462
# std         0.460288
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# Use Pandas Plotting with Matplotlib to plot the data
percipitation_last_12_months_df.plot()
plt.xlabel("date")
plt.ylabel("percipitation")
plt.title("12 Months Percipitation Data")
plt.xticks(rotation=90)
plt.savefig("12 Months Percipitation Data.png")
plt.show()

# %%
# Design a query to show how many stations are available in this dataset?
station_count = session.query(Station.id).count()

station_count
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).\
group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
filter(Measurement.station == 'USC00519281').all()
# Station USC00519281 is the most active station
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
highest_temp = session.query(Measurement.tobs).\
filter(Measurement.date >='2016-08-23').all()

station_highest_temp = pd.DataFrame(highest_temp, columns=["tobs"])
station_highest_temp.plot.hist(bins=12)
plt.savefig("Last 12 Months Temperature.png")
plt.show()

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
trip_begin = dt.date(2016, 9, 15)
trip_end = dt.date(2016, 9, 30)

start_date = trip_begin - dt.timedelta(days=365)
end_date = trip_end - dt.timedelta(days=365)

trip_temp = calc_temps(start_date, end_date)
trip_temp
# Out:
# [(71.0, 78.00877192982456, 83.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
fig, ax = plt.subplots(figsize=plt.figaspect(2.))
trip_avg_temp = trip_temp[0][1]
xpos = 1
error = trip_temp[0][2]- trip_temp[0][1]
bar_chart = ax.bar(xpos, trip_avg_temp, yerr= error,alpha=0.5, color='orange')
ax.set(xticks= range(xpos), title="Trip Avg Temp", ylabel="Average Temperature (F)")
fig.tight_layout()
plt.savefig("Trip Avg Temp.png")

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
trip_begin = dt.date(2016, 9, 15)
trip_end = dt.date(2016, 9, 30)

sel = [Station.station, Station.name, Station.latitude, Station.longitude,Station.elevation, func.sum(Measurement.prcp)]
results = session.query(*sel).\
filter(Measurement.station ==Station.station).\
filter(Measurement.date >=trip_begin).\
filter(Measurement.date <=trip_end).\
group_by(Station.name).order_by(func.sum(Measurement.prcp).desc()).all()

result_output = pd.DataFrame(np.array(results))
result_output = result_output.rename(columns={0:'Station', 1: 'Location',
                                            2: 'Total Precipitation', 3: 'Latitude',
                                             4: 'Longitude', 5: 'Elevation'})

result_output
# Out:
#        Station                                Location Total Precipitation  \
# 0  USC00516128            MANOA LYON ARBO 785.2, HI US             21.3331
# 1  USC00519281                     WAIHEE 837.5, HI US            21.45167
# 2  USC00513117                    KANEOHE 838.1, HI US             21.4234
# 3  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US            21.33556
# 4  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US             21.5213
# 5  USC00519397                    WAIKIKI 717.2, HI US             21.2716
# 6  USC00517948                       PEARL CITY, HI US             21.3934
#
#               Latitude Longitude           Elevation
# 0            -157.8025     152.4  11.640000000000002
# 1  -157.84888999999998      32.9   4.119999999999999
# 2            -157.8015      14.6  1.6500000000000001
# 3           -157.71139      19.5                1.04
# 4            -157.8374       7.0  1.0100000000000002
# ...

# %%
###### Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip
trip_begin = 15
trip_end = 30

# Use the start and end date to create a range of dates
dates = [dt.date(2016,9,i) for i in range(trip_begin,trip_end)]

# Stip off the year and save a list of %m-%d strings
stripped_dates = [date.strftime('%m-%d') for date in dates]

# Loop through the list of %m-%d strings and calculate the normals for each date
date_normals = list()

for stripped_date in stripped_dates:
    date_normals.append(*daily_normals(stripped_date))

# %%
date_normals
# Out:
# [(67.0, 76.14, 81.0),
#  (70.0, 77.40384615384616, 86.0),
#  (68.0, 76.57692307692308, 83.0),
#  (67.0, 75.85106382978724, 84.0),
#  (68.0, 76.34693877551021, 87.0),
#  (69.0, 76.14583333333333, 83.0),
#  (67.0, 76.44897959183673, 84.0),
#  (69.0, 76.37254901960785, 84.0),
#  (67.0, 75.82692307692308, 83.0),
#  (69.0, 77.02, 85.0),
#  (69.0, 76.14893617021276, 83.0),
#  (66.0, 75.64, 85.0),
#  (68.0, 75.64, 83.0),
#  (67.0, 76.13461538461539, 84.0),
#  (68.0, 75.97872340425532, 83.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

date_normals_df = pd.DataFrame(date_normals, columns=['tmin', 'tavg', 'tmax'])
date_normals_df['dates']= dates
date_normals_df = date_normals_df.set_index('dates')

date_normals_df
# Out:
#             tmin       tavg  tmax
# dates
# 2016-09-15  67.0  76.140000  81.0
# 2016-09-16  70.0  77.403846  86.0
# 2016-09-17  68.0  76.576923  83.0
# 2016-09-18  67.0  75.851064  84.0
# 2016-09-19  68.0  76.346939  87.0
# 2016-09-20  69.0  76.145833  83.0
# 2016-09-21  67.0  76.448980  84.0
# 2016-09-22  69.0  76.372549  84.0
# 2016-09-23  67.0  75.826923  83.0
# 2016-09-24  69.0  77.020000  85.0
# 2016-09-25  69.0  76.148936  83.0
# 2016-09-26  66.0  75.640000  85.0
# 2016-09-27  68.0  75.640000  83.0
# 2016-09-28  67.0  76.134615  84.0
# 2016-09-29  68.0  75.978723  83.0

# %%
# Plot the daily normals as an area plot with `stacked=False`

date_normals_df.plot.area(stacked = False,xticks = list(date_normals_df.index)[::1],rot = 'vertical')
plt.savefig("Daily Normals.png")
